# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# The path to our CSV file
file = "data/most-recent-cohorts-all-data-elements-csv-5.csv"

# Read our Kickstarter data into pandas
df5 = pd.read_csv(file)
df5.head()
# Out:
# C:\Users\tpatel\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6,9,1608,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1688,1689,1690,1691,1692,1703,1704,1725,1726,1727,1728,1729,1743) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP                                       ACCREDAGENCY  \
# ...

# %%
file2="data/most-recent-cohorts-treasury-elements-csv-3.csv"
df3=pd.read_csv(file2)
df3
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7588  48154401  4220901   42209
# 7589  48387801  4223701   42237
# 7590  48400201  4228101   42281
# 7591  48414501  4232401   42324
# 7592  48621101  4215601   42156
#
#                                                  INSTNM  COUNT_ED  \
# 0                              Alabama A & M University       NaN
# 1                   University of Alabama at Birmingham       NaN
# 2                                    Amridge University       NaN
# 3                   University of Alabama in Huntsville       NaN
# 4                              Alabama State University       NaN
# ...                                                 ...       ...
# 7588  National Personal Training Institute of Cleveland       NaN
# ...

# %% [markdown]
# ### Data Transformation - take select columns needed

# %%
clean_df5=df5[["UNITID","OPEID","INSTNM","HIGHDEG","CONTROL","SCH_DEG","UGDS","PPTUG_EF","ADM_RATE","CITY","STABBR",
              "ZIP","LATITUDE","LONGITUDE","INSTURL","POVERTY_RATE","UNEMP_RATE","FAMINC","MD_FAMINC","FAMINC_IND",
              "TUITFTE","INEXPFTE","AVGFACSAL","NPT4_PUB","NPT4_PRIV","COSTT4_A","COSTT4_P","RELAFFIL","ACCREDAGENCY"]]
clean_df5
# Out:
#         UNITID    OPEID                                             INSTNM  \
# 0       100654   100200                           Alabama A & M University
# 1       100663   105200                University of Alabama at Birmingham
# 2       100690  2503400                                 Amridge University
# 3       100706   105500                University of Alabama in Huntsville
# 4       100724   100500                           Alabama State University
# ...        ...      ...                                                ...
# 7588  48154401  4220901  National Personal Training Institute of Cleveland
# 7589  48387801  4223701  Bay Area Medical Academy - San Jose Satellite ...
# 7590  48400201  4228101                        High Desert Medical College
# 7591  48414501  4232401                        Vantage College-San Antonio
# 7592  48621101  4215601  American Institute of Pharmaceutical Technolog...
#
#       HIGHDEG  CONTROL  SCH_DEG     UGDS  PPTUG_EF  ADM_RATE  \
# ...

# %%
clean_df3=df3[["UNITID","OPEID","PCT_WHITE","PCT_BLACK","PCT_ASIAN","PCT_HISPANIC","PCT_BA","PCT_BORN_US"]]
clean_df3
# Out:
#         UNITID    OPEID         PCT_WHITE         PCT_BLACK         PCT_ASIAN  \
# 0       100654   100200  46.8400001525878  47.9799995422363  1.48000001907348
# 1       100663   105200  69.0199966430664  27.7600002288818  1.10000002384185
# 2       100690  2503400  70.8799972534179  22.5300006866455  1.28999996185302
# 3       100706   105500  76.3799972534179  18.9799995422363  1.41999995708465
# 4       100724   100500  42.6899986267089  52.3199996948242  1.40999996662139
# ...        ...      ...               ...               ...               ...
# 7588  48154401  4220901               NaN               NaN               NaN
# 7589  48387801  4223701               NaN               NaN               NaN
# 7590  48400201  4228101               NaN               NaN               NaN
# 7591  48414501  4232401               NaN               NaN               NaN
# 7592  48621101  4215601               NaN               NaN               NaN
#
# ...

# %%
# Merge all data frames into a master data frame to work with
master_df = clean_df5.merge(clean_df3, on=['UNITID', 'OPEID'])
master_df
# Out:
#         UNITID    OPEID                                             INSTNM  \
# 0       100654   100200                           Alabama A & M University
# 1       100663   105200                University of Alabama at Birmingham
# 2       100690  2503400                                 Amridge University
# 3       100706   105500                University of Alabama in Huntsville
# 4       100724   100500                           Alabama State University
# ...        ...      ...                                                ...
# 7588  48154401  4220901  National Personal Training Institute of Cleveland
# 7589  48387801  4223701  Bay Area Medical Academy - San Jose Satellite ...
# 7590  48400201  4228101                        High Desert Medical College
# 7591  48414501  4232401                        Vantage College-San Antonio
# 7592  48621101  4215601  American Institute of Pharmaceutical Technolog...
#
#       HIGHDEG  CONTROL  SCH_DEG     UGDS  PPTUG_EF  ADM_RATE  \
# ...

# %% [markdown]
# ### Create Seperate Table Specific CSVs

# %%
profiles_df = master_df[['UNITID', 'OPEID', 'INSTNM', 'CONTROL', 'SCH_DEG', 'RELAFFIL', 'HIGHDEG', 'INSTURL']]
profiles_df.head()
# Out:
#    UNITID    OPEID                               INSTNM  CONTROL  SCH_DEG  \
# 0  100654   100200             Alabama A & M University        1      3.0
# 1  100663   105200  University of Alabama at Birmingham        1      3.0
# 2  100690  2503400                   Amridge University        2      3.0
# 3  100706   105500  University of Alabama in Huntsville        1      3.0
# 4  100724   100500             Alabama State University        1      3.0
#
#    RELAFFIL  HIGHDEG                    INSTURL
# 0       NaN        4              www.aamu.edu/
# 1       NaN        4                www.uab.edu
# 2      74.0        4  www.amridgeuniversity.edu
# 3       NaN        4                www.uah.edu
# 4       NaN        4              www.alasu.edu

# %%
costs_df = master_df[['UNITID','TUITFTE', 'INEXPFTE', 'AVGFACSAL', 'NPT4_PRIV', 'NPT4_PUB', 'COSTT4_A', 'COSTT4_P']]
costs_df.head()
# Out:
#    UNITID  TUITFTE  INEXPFTE  AVGFACSAL  NPT4_PRIV  NPT4_PUB  COSTT4_A  \
# 0  100654   9657.0    7941.0     7017.0        NaN   13435.0   20809.0
# 1  100663  10263.0   17548.0    10221.0        NaN   16023.0   22232.0
# 2  100690  17071.0    7113.0     3217.0     8862.0       NaN   12133.0
# 3  100706   8917.0   10619.0     9514.0        NaN   18661.0   20999.0
# 4  100724   7717.0    7742.0     7940.0        NaN    7400.0   18100.0
#
#    COSTT4_P
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
demographics_df = master_df[['UNITID','PCT_WHITE', 'PCT_BLACK', 'PCT_ASIAN', 'PCT_HISPANIC', 'PCT_BA', 'PCT_BORN_US']]
demographics_df.head()
# Out:
#    UNITID         PCT_WHITE         PCT_BLACK         PCT_ASIAN  \
# 0  100654  46.8400001525878  47.9799995422363  1.48000001907348
# 1  100663  69.0199966430664  27.7600002288818  1.10000002384185
# 2  100690  70.8799972534179  22.5300006866455  1.28999996185302
# 3  100706  76.3799972534179  18.9799995422363  1.41999995708465
# 4  100724  42.6899986267089  52.3199996948242  1.40999996662139
#
#        PCT_HISPANIC            PCT_BA       PCT_BORN_US
# 0  3.78999996185302                13  94.7399978637695
# 1  2.02999997138977  15.9300003051757              96.5
# 2  6.94000005722046  13.2299995422363  94.0899963378906
# 3  2.54999995231628  17.6700000762939  95.2699966430664
# 4  4.09000015258789  11.8100004196167  94.5299987792968

# %%
enrollment_df = master_df[['UNITID','ADM_RATE', 'UGDS', 'PPTUG_EF']]
enrollment_df.head()
# Out:
#    UNITID  ADM_RATE     UGDS  PPTUG_EF
# 0  100654    0.6538   4505.0    0.0626
# 1  100663    0.6043  11269.0    0.2671
# 2  100690       NaN    308.0    0.5714
# 3  100706    0.8120   5829.0    0.1911
# 4  100724    0.4639   4740.0    0.0766

# %%
geography_df = master_df[['UNITID','CITY', 'STABBR', 'ZIP', 'LATITUDE', 'LONGITUDE']]
geography_df.head()
# Out:
#    UNITID        CITY STABBR         ZIP   LATITUDE  LONGITUDE
# 0  100654      Normal     AL       35762  34.783368 -86.568502
# 1  100663  Birmingham     AL  35294-0110  33.502230 -86.809170
# 2  100690  Montgomery     AL  36117-3553  32.362609 -86.174010
# 3  100706  Huntsville     AL       35899  34.722818 -86.638420
# 4  100724  Montgomery     AL  36104-0271  32.364317 -86.295677

# %%
need_df = master_df[['UNITID','FAMINC', 'MD_FAMINC', 'FAMINC_IND']]
need_df.head()
# Out:
#    UNITID        FAMINC MD_FAMINC    FAMINC_IND
# 0  100654  30489.792062     21429  8487.4347826
# 1  100663  50315.256601     33731  29795.357579
# 2  100690   19593.14652     14631  18765.062241
# 3  100706  55624.221251   39100.5  25075.698438
# 4  100724   30857.27722     21704   6715.964497

# %%
outcomes_df = master_df[['UNITID','POVERTY_RATE', 'UNEMP_RATE']]
outcomes_df.head()
# Out:
#    UNITID      POVERTY_RATE        UNEMP_RATE
# 0  100654  14.8800001144409  4.84000015258789
# 1  100663  10.9099998474121  3.45000004768371
# 2  100690  10.6499996185302  3.59999990463256
# 3  100706  9.36999988555908  3.64000010490417
# 4  100724  16.9599990844726  4.80999994277954

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/etl_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Upload Data

# %%
profiles_df.to_sql(name='Profiles', con=engine, index=False)

# %%
costs_df.to_sql(name='Costs', con=engine, index=False)

# %%
demographics_df.to_sql(name='Demographics', con=engine, index=False)

# %%
enrollment_df.to_sql(name='Enrollment', con=engine, index=False)

# %%
geography_df.to_sql(name='Geography', con=engine, index=False)

# %%
need_df.to_sql(name='Need', con=engine, index=False)

# %%
outcomes_df.to_sql(name='Outcomes', con=engine, index=False)

# %% [markdown]
# ### Confirm data has been added by querying the tables

# %%
pd.read_sql_query('select * from "Profiles"', con=engine).head()
# Out:
#    UNITID    OPEID                               INSTNM  CONTROL  SCH_DEG  \
# 0  100654   100200             Alabama A & M University        1      3.0
# 1  100663   105200  University of Alabama at Birmingham        1      3.0
# 2  100690  2503400                   Amridge University        2      3.0
# 3  100706   105500  University of Alabama in Huntsville        1      3.0
# 4  100724   100500             Alabama State University        1      3.0
#
#    RELAFFIL  HIGHDEG                    INSTURL
# 0       NaN        4              www.aamu.edu/
# 1       NaN        4                www.uab.edu
# 2      74.0        4  www.amridgeuniversity.edu
# 3       NaN        4                www.uah.edu
# 4       NaN        4              www.alasu.edu

# %%
pd.read_sql_query('select * from "Profiles"', con=engine).head()
# Out:
#    UNITID    OPEID                               INSTNM  CONTROL  SCH_DEG  \
# 0  100654   100200             Alabama A & M University        1      3.0
# 1  100663   105200  University of Alabama at Birmingham        1      3.0
# 2  100690  2503400                   Amridge University        2      3.0
# 3  100706   105500  University of Alabama in Huntsville        1      3.0
# 4  100724   100500             Alabama State University        1      3.0
#
#    RELAFFIL  HIGHDEG                    INSTURL
# 0       NaN        4              www.aamu.edu/
# 1       NaN        4                www.uab.edu
# 2      74.0        4  www.amridgeuniversity.edu
# 3       NaN        4                www.uah.edu
# 4       NaN        4              www.alasu.edu

# %%
pd.read_sql_query('select * from "Costs"', con=engine).head()
# Out:
#    UNITID  TUITFTE  INEXPFTE  AVGFACSAL  NPT4_PRIV  NPT4_PUB  COSTT4_A  \
# 0  100654   9657.0    7941.0     7017.0        NaN   13435.0   20809.0
# 1  100663  10263.0   17548.0    10221.0        NaN   16023.0   22232.0
# 2  100690  17071.0    7113.0     3217.0     8862.0       NaN   12133.0
# 3  100706   8917.0   10619.0     9514.0        NaN   18661.0   20999.0
# 4  100724   7717.0    7742.0     7940.0        NaN    7400.0   18100.0
#
#    COSTT4_P
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
pd.read_sql_query('select * from "Demographics"', con=engine).head()
# Out:
#    UNITID         PCT_WHITE         PCT_BLACK         PCT_ASIAN  \
# 0  100654  46.8400001525878  47.9799995422363  1.48000001907348
# 1  100663  69.0199966430664  27.7600002288818  1.10000002384185
# 2  100690  70.8799972534179  22.5300006866455  1.28999996185302
# 3  100706  76.3799972534179  18.9799995422363  1.41999995708465
# 4  100724  42.6899986267089  52.3199996948242  1.40999996662139
#
#        PCT_HISPANIC            PCT_BA       PCT_BORN_US
# 0  3.78999996185302                13  94.7399978637695
# 1  2.02999997138977  15.9300003051757              96.5
# 2  6.94000005722046  13.2299995422363  94.0899963378906
# 3  2.54999995231628  17.6700000762939  95.2699966430664
# 4  4.09000015258789  11.8100004196167  94.5299987792968

# %%
pd.read_sql_query('select * from "Enrollment"', con=engine).head()
# Out:
#    UNITID  ADM_RATE     UGDS  PPTUG_EF
# 0  100654    0.6538   4505.0    0.0626
# 1  100663    0.6043  11269.0    0.2671
# 2  100690       NaN    308.0    0.5714
# 3  100706    0.8120   5829.0    0.1911
# 4  100724    0.4639   4740.0    0.0766

# %%
pd.read_sql_query('select * from "Geography"', con=engine).head()
# Out:
#    UNITID        CITY STABBR         ZIP   LATITUDE  LONGITUDE
# 0  100654      Normal     AL       35762  34.783368 -86.568502
# 1  100663  Birmingham     AL  35294-0110  33.502230 -86.809170
# 2  100690  Montgomery     AL  36117-3553  32.362609 -86.174010
# 3  100706  Huntsville     AL       35899  34.722818 -86.638420
# 4  100724  Montgomery     AL  36104-0271  32.364317 -86.295677

# %%
pd.read_sql_query('select * from "Need"', con=engine).head()
# Out:
#    UNITID        FAMINC MD_FAMINC    FAMINC_IND
# 0  100654  30489.792062     21429  8487.4347826
# 1  100663  50315.256601     33731  29795.357579
# 2  100690   19593.14652     14631  18765.062241
# 3  100706  55624.221251   39100.5  25075.698438
# 4  100724   30857.27722     21704   6715.964497

# %%
pd.read_sql_query('select * from "Outcomes"', con=engine).head()
# Out:
#    UNITID      POVERTY_RATE        UNEMP_RATE
# 0  100654  14.8800001144409  4.84000015258789
# 1  100663  10.9099998474121  3.45000004768371
# 2  100690  10.6499996185302  3.59999990463256
# 3  100706  9.36999988555908  3.64000010490417
# 4  100724  16.9599990844726  4.80999994277954
